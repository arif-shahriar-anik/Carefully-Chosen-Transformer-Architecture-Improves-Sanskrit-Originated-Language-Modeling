# %%
from datasets import load_dataset

column_names=["labels","text"]
train_dataset = load_dataset("csv", data_files="..\datasets\iitp-product-reviews\hi\hi-train.csv", split="train", column_names=column_names, delimiter=',')
# Out:
# Using custom data configuration default-cf2dc84d42ef9241
# Found cached dataset csv (C:/Users/arifa/.cache/huggingface/datasets/csv/default-cf2dc84d42ef9241/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)

# %%
temp_train.reset_format()

# %%
val_dataset = load_dataset("csv", data_files="..\datasets\iitp-product-reviews\hi\hi-valid.csv", split="train", column_names=["labels","text"], delimiter=',')
# Out:
# Using custom data configuration default-800cf891d22db47b
# Found cached dataset csv (C:/Users/arifa/.cache/huggingface/datasets/csv/default-800cf891d22db47b/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)

# %%
test_dataset = load_dataset("csv", data_files="..\datasets\iitp-product-reviews\hi\hi-test.csv", split="train", column_names=["labels","text"], delimiter=',')
# Out:
# Using custom data configuration default-dc28a06aa2a6c39c
# Found cached dataset csv (C:/Users/arifa/.cache/huggingface/datasets/csv/default-dc28a06aa2a6c39c/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)

# %%
from datasets import Dataset, DatasetDict

review_datasets = DatasetDict()
review_datasets['train'] = train_dataset
review_datasets['validation'] = val_dataset
review_datasets['test'] = test_dataset

# %%
review_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['labels', 'text'],
#         num_rows: 4182
#     })
#     validation: Dataset({
#         features: ['labels', 'text'],
#         num_rows: 523
#     })
#     test: Dataset({
#         features: ['labels', 'text'],
#         num_rows: 523
#     })
# })

# %%
train_dataset.set_format("pandas")

# %%
# get label counts for both classes
label_counts = train_dataset["labels"].value_counts()
num_labels = (len(label_counts.keys()))

# %%
label_counts
# Out:
# positive    1826
# neutral     1789
# negative     567
# Name: labels, dtype: int64

# %%
max_token_length = max(train_dataset['text'].str.len())
max_token_length
# Out:
# 354

# %%
train_dataset.reset_format()

# %%
from transformers import set_seed

set_seed(30)
# set_seed(42)

# %%
from transformers import PreTrainedTokenizerFast, AutoModelForSequenceClassification

tokenizer = PreTrainedTokenizerFast.from_pretrained("../Hindi Pretraining/models/unigram/bert-base-pretrained-hindi")

# %%
model =  AutoModelForSequenceClassification.from_pretrained("../Hindi Pretraining/models/unigram/bert-base-pretrained-hindi", num_labels=num_labels)
# Out:
# Some weights of the model checkpoint at ../Hindi Pretraining/models/unigram/bert-base-pretrained-hindi were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at ../Hindi Pretraining/models/unigram/bert-base-pretrained-hindi and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# num_added_tokens = tokenizer.add_tokens(["5","7","8","9"])

# %%
# Notice: resize_token_embeddings expect to receive the full size of the new vocabulary, i.e., the length of the tokenizer.
# model.resize_token_embeddings(len(tokenizer))

# %%
def tokenize_function(example):
    return tokenizer(example["text"], truncation=True)
    #return tokenizer(example["text"], truncation=True, max_length=128)

# %%
from transformers import DataCollatorWithPadding

tokenized_datasets = review_datasets.map(tokenize_function, batched=True, remove_columns=["text"])
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
# Out:
# Loading cached processed dataset at C:\Users\arifa\.cache\huggingface\datasets\csv\default-cf2dc84d42ef9241\0.0.0\6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317\cache-9db2394ff80575a0.arrow
# Loading cached processed dataset at C:\Users\arifa\.cache\huggingface\datasets\csv\default-800cf891d22db47b\0.0.0\6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317\cache-e06673b5ed80ddab.arrow
# Loading cached processed dataset at C:\Users\arifa\.cache\huggingface\datasets\csv\default-dc28a06aa2a6c39c\0.0.0\6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317\cache-938e5d67ecabcb51.arrow

# %%
tokenized_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['labels', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 4182
#     })
#     validation: Dataset({
#         features: ['labels', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 523
#     })
#     test: Dataset({
#         features: ['labels', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 523
#     })
# })

# %%
# tokenized_datasets = tokenized_datasets.filter(lambda x:x if x["labels"] != 'neutral' else None)

# %%
temp = tokenized_datasets.filter(lambda x:x if 0 in x["input_ids"] else None)
# Out:
# Loading cached processed dataset at C:\Users\arifa\.cache\huggingface\datasets\csv\default-cf2dc84d42ef9241\0.0.0\6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317\cache-bd9a79f86a8d3d6a.arrow
# Loading cached processed dataset at C:\Users\arifa\.cache\huggingface\datasets\csv\default-800cf891d22db47b\0.0.0\6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317\cache-ed0b08c4be0f503a.arrow
# Loading cached processed dataset at C:\Users\arifa\.cache\huggingface\datasets\csv\default-dc28a06aa2a6c39c\0.0.0\6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317\cache-1b2b19c4b95cd197.arrow

# %%
temp
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['labels', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 987
#     })
#     validation: Dataset({
#         features: ['labels', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 112
#     })
#     test: Dataset({
#         features: ['labels', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 119
#     })
# })

# %%
for sample in temp["train"]:
    print(tokenizer.decode(sample["input_ids"]))
# Out:
# [CLS] युवाओं के लिए यह फोन कमजोर रैम के कारण बहुत ज्यादा उपयुक्त नहीं है, मध्यमवर्गीय और 2[UNK] साल से अधिक आयु के कामकाजी लोग, गृहिणियां यां स्कूली छात्र चाहें तो इसे अपने पहले मोबाईल फोन के तौर पर आजमा सकते हैं ।[SEP]
# [CLS] इसमें [UNK].[UNK] इंच का एचडी डिस्पले स्क्रीन अल्ट्रा वाइड व्यूइंग एंगल के साथ दी गई है जिससे पिक्चर्स बेहतर क्वालिटी में दिखती है ।[SEP]
# [CLS] ये सभी बातें [UNK] एवेंजर्स : एज ऑफ अल्ट्रॉन [UNK] में देखने को मिलती है ।[SEP]
# [CLS] सबसे अहम् बात ये है की डिज़ाइन और लुक्स के मामले में ये लेनोवो जेड[UNK]0 से कहीं आगे है, इसे निश्चित रूप से एक बेहतर चुनाव कहा जा सकता है ।[SEP]
# [CLS] यह टैबलेट एंड्रॉयड 4.4 [UNK]it[UNK]at के साथ आता है |[SEP]
# [CLS] एप्पल के नए 1[UNK] इंच लैपटॉप में 16 [UNK] इंटरनल मेमोरी के साथ 2.2 [UNK] का क्वाड कोर इंटेल कोर प्रोसेसर दिया गया है ।[SEP]
# [CLS] इसके 10.1-इंच डिस्प्ले का रेजोल्यूशन 1[UNK]20 [UNK] 1200 पिक्सेल है, जो इसे 224 पीपीआई का पिक्सेल डेंसिटी देता है ।[SEP]
# [CLS] गैलेक्सी नोट [UNK]00 का लॉक स्क्रीन सिंपल और अच्छा है ।[SEP]
# [CLS] [UNK] हैदर [UNK] की खोज है नरेंद्र झा ।[SEP]
# [CLS] हुवैई मीडिया पैड में डुअल कैमरा है, एक [UNK] मेगापिक्सल ऑटोफोकस उच्च डेफीनिशन वाला पिछला एवं 1.3 मेगापिक्सल का सामने वाला कैमरा चैटिंग के लिए ।[SEP]
# [CLS] ये खुबसूरत टेबलेट 2[UNK] वाले इंटेल एटम 2[UNK]0 प्रोसेसर दवारा संचालित है इसका प्रदर्शन बहुत उम्दा है |[SEP]
# [CLS] यह इसको एक तरफ रू. [UNK]000 की कीमत वाले हार्इ एण्ड ऑरवाना2, माइक्रोस [UNK]0 तथा एक्सबीए 3 और एक्सट्रीम हार्इ एण्ड कीमत वाले यूर्इ[UNK]000 और क्यूसी20आर्इ के बीच में रखता है जिसकी कीमत रू. 2[UNK],000 से भी अधिक है ।[SEP]
# [CLS] कंपनी ने इसमें 13 मेगापिक्सल कैमरा डयूल एलईडी फ्लैश के साथ पीछे और [UNK] मेगापिक्सल कैमरा [UNK] डिग्री वाइड एंगल के आगे की तरफ दिया गया है ।[SEP]
# [CLS] यह 4[UNK] एंड्रॉइड टीवी बॉक्स है ।[SEP]
# [CLS] कनेक्टिविटी के लिए वाई - फाई, ब्‍लूटूथ और [UNK] की सुविधा दी गई है ।[SEP]
# [CLS] ज़ेडटीइ वी[UNK] में [UNK] इंच डिस्प्ले है और बनावट ज्यादातर प्लास्टिक की है और बैक निकाली जा सकती है ।[SEP]
# [CLS] बैटरी स्टेटिस्टिक्स की बात करें तो, सेल - स्टेंडबाई प्रोसेस हाई कॉन्सम्पशन प्रतिशत दिखाता है जो कि आदर्श रूप से 1[UNK] से 20 फीसदी से अधिक नहीं होना चाहिए था ।[SEP]
# [CLS] मेमोरी की बात करें, तो आसुस ने इस अल्ट्राबुक में [UNK]12[UNK] [UNK] हार्ड डिस्क दी है ।[SEP]
# [CLS] सैमसंग ने अपनी इस डिवाइस [UNK]ear [UNK] का डिजाइन बहुत ही सुविधाजनक तरीके से तैयार किया है ।[SEP]
# [CLS] आईफ़ोन [UNK] में लगा ए6 प्रोसेसर भी काफी शक्तिशाली था ।[SEP]
# [CLS] माइक्रोमैक्स केनवस टेब पी4[UNK]0 में 1 जीबी रैम और 1.3 गीगाहर्त्ज क्वॉडकोर प्रोसेसर दिया गया है जिससें इसकी प्रोसेसिंग स्पीड अच्छी है ।[SEP]
# [CLS] 3.1[UNK] मेगापिक्सेल कैमरा [UNK]20पी एचडी वीडियो रिकार्डिंग के साथ ।[SEP]
# [CLS] नोट 4 फ्लैगशिप डिवाइस है हालांकि यह नेक्सस [UNK] की तरह स्मूथ नहीं है ।[SEP]
# [CLS] ग्राफ़िक्स बेंचमार्क टेस्ट में लेनोवो आइडियापैड जेड[UNK]00 का परफॉरमेंस बेहद शानदार है ।[SEP]
# [CLS] इसी कीमत में अन्य स्मार्टफोन भी है जो ऐसे ही या इससे भी बढ़कर विशेषताएं प्रदान कर रहे हैं, लेकिन अगर ईमानदारी से कहा जाए तो मोटो जी सच में [UNK]नो - नॉनसेंस[UNK] बजट ऍण्ड्रॉइड स्मार्टफोन है ।[SEP]
# [CLS] साथ ही इसमें प्रयोग करने के लिए आपको डाटा डॉन्गल्स प्रयोग करने के लिए [UNK] एडॉप्टर या [UNK] ड्राइव खरीदने की जरूरत नहीं हैं क्योंकि यह इसके बॉक्स के साथ ही मिलते हैं ।[SEP]
# [CLS] इसके आगे, हमने एक फुल एचडी फाइल फुल ब्राइटनेसपर, वाइफाइ अनेबल्ड और एक सिम कार्ड के साथ एक घंटा चलाई, एक घंटे के प्लेबैक के बाद बैट्री 100 % से [UNK] % तक ही उतरी जो की बहुत ही जबरदस्त प्रदर्शन रहा था ।[SEP]
# [CLS] यह टेबलेट [UNK] जीबी / 16 जीबी / 32 जीबी स्टोरेज क्षमता में आता है, इसके मेमोरी को माइक्रो एसडी कार्ड से 32 जीबी तक बढ़ाया जा सकता है ।[SEP]
# [CLS] [UNK] अपने स्मार्टफोन [UNK]3 को इस हफ्ते एंड्रायड लॉलीपॉप से अपडेट करने वाला है जबकि इस मामले में गूगल के डिवाइसेज अभी पीछे हैं ।[SEP]
# [CLS] बुनियादी रूप से टैबलेट माइक्रोमैक्स Microma[UNK] के पहले के टैबलेट फनबुक [UNK]unbook का अपग्रेडेट वर्जन है ।[SEP]
# [CLS] साथ ही इसमें 1.2 जीएचजेड क्वालकॉम स्नैपड्रगन 400 डुअल कोर प्रोसेर व 1.[UNK] जीबी का रैम है ।[SEP]
# [CLS] वल्र्ड हेरिटेज डे की शुरुआत 1[UNK] अप्रैल, 1[UNK]2 को हुई थी, जब इकोमास इंटरनेशनल काउंसिल ऑन मोन्यूमेंट्स ऐंड साइट्स, यह संस्था इस साल अपना [UNK]0वीं 1[UNK]6[UNK]-201[UNK] एनिवर्सरी सेलिब्रेटकर रही है ने ट्यूनीशिया में इंटरनेशनल डे फॉर मोन्यूमेंट्स ऐंड साइट का आयोजन किया था ।[SEP]
# [CLS] 13 मेगापिक्सल का रीयर कैमरा है जबकि फ्रंट कैमरा [UNK] मेगापिक्सल का है ।[SEP]
# [CLS] इसमें [UNK].[UNK] इंच की डिस्पले स्क्रीन कॉर्निग गोरिल्ला ग्लास3 प्रोटेक्शन के साथ दी गई है ।[SEP]
# [CLS] सोनी के इन नए कैमरों की रेंज में सबसे हाई एंड कैमरा ए[UNK]एस है जो 4के वीडियो क्वालिटी वाला है ।[SEP]
# [CLS] स्क्रीन का रिजोल्यूशन [UNK]00[UNK]600 है ।[SEP]
# [CLS] बनावट अगर देखें तो बाजार में इंट्री - लेवल पर उपलब्ध अन्य डीएसएलआर के मुकाबले के-[UNK]00 ज्यादा भारी है ।[SEP]
# [CLS] इसमें [UNK]00 जीबी की हार्ड डिस्क और दो जीबी रैम है जो 2.30 गीगाहर्टज इंटेल पेंटियम प्रोसेसर के साथ काम करने की स्पीड को बेहतर बनाता है ।[SEP]
# [CLS] हमारी सलाह यह है कि इसे खरीदने का निर्णय करते समय आप इससे थोड़े से महंगे गैलेक्सी टैब [UNK]30 को भी अवश्य ध्यान में रखें ।[SEP]
# [CLS] यदि यह एक [UNK] सामान्य [UNK] कीमत टैग के साथ एक प्रमुख डिवाइस होता, तो हम सभी इसे पसंद करते ।[SEP]
# [CLS] आइडियापैड जेड[UNK]0 की परफॉरमेंस शानदार है और एन्वी डीवी6-[UNK]206टीएक्स इसके काफी करीब रहता है ।[SEP]
# [CLS] 1024 [UNK] 600 पिक्सेल रेजोल्यूशन का [UNK]-इंच पीएलएस एलसीडी डिस्प्ले है ।[SEP]
# [CLS] पिक्चर क्वालिटी, रॉ [UNK] और जेपीइजी [UNK] तो प्रभावित करता है, पर इसके अलावा भी एक बेहद लाभकारी फीचर इसमें है ।[SEP]
# [CLS] इस लैपटॉप में भी 16[UNK] की इंटरनल मेमोरी है ।[SEP]
# [CLS] भारी इस्तेमाल करने वालों के लिए नेक्सस [UNK] एक बेहतर विकल्प है, क्योंकि इस टेबलेट में बढ़िया डिस्प्ले और ज्यादा शक्ति है ।[SEP]
# [CLS] 20 हजार रु की कीमत में खूबसूरत सी डिजाइन वाला [UNK] इंच का फोन मिलता है ।[SEP]
# [CLS] सैमसंग गैलेक्सी नोट [UNK]00 में 10.1-इंच का डिस्प्ले, फ्रंट फेसिंग कैमरा, लाइट सेंसर और स्क्रीन के दोनों तरफ दो स्पीकर्स हैं ।[SEP]
# [CLS] [UNK] जेड प्लस [UNK] कंटेंट प्रधान फिल्म है ।[SEP]
# [CLS] लूमिया [UNK]40, कम दाम में ज्‍यादा काम ।[SEP]
# [CLS] इसमें दो कमियां हैं जिन पर पहले से ही ध्यान देना चाहिए - सिम्बियन ^ 3 [UNK]ymbian ^ 3 आधारित बेले [UNK]elle मोबाइल ओएस [UNK] और मोटाई के साथ भारी होना ।[SEP]
# [CLS] इस फ़ोन में ऑप्टिकल इमेज स्टेबिलाइजेशन के साथ 13 मेगापिक्सेल रियर कैमरा भी है, इसके कनेक्टिविटी ऑप्शन्स में 4[UNK], [UNK]T[UNK], 3[UNK], ब्लूटूथ, यूएसबी और वाई - फाई हैं ।[SEP]
# [CLS] इसके साथ ही आपको इसमें एक 3200m[UNK]h क्षमता की बैटरी भी मिल रही है ।[SEP]
# [CLS] [UNK]300 में 3.2 इंच की एलसीडी स्‍क्रीन दी गई है ।[SEP]
# [CLS] इसमें 20 एमपी सेंसर, [UNK]एक्स ऑप्टिकल जूम, 2.[UNK] इंच एलसीडी डिस्पले, 230 शॉट बैटरी दिए गए हैं ।[SEP]
# [CLS] लिनोवो के दूसरे मॉडल ए 3000 में [UNK] इंच की आईपीएस स्‍क्रीन दी गई है, जो 1024[UNK]600 पिक्‍सल सपोर्ट करती है ।[SEP]
# [CLS] सिस्टम परफॉरमेंस टेस्ट पीसी मार्क 0[UNK] में एन्वी का स्कोर 3420 रहा जबकि जेड[UNK]0 का स्कोर 3426 है ।[SEP]
# [CLS] इसके साथ ही इस नए स्मार्टफ़ोन में 64-बिट इंटेल एटम 1.[UNK] प्रोसेसर, 4[UNK] रैम के साथ है इसके अलावा इस फ़ोन में 64[UNK] की इंटरनल स्टोरेज भी है जिसे आप 12[UNK] तक एक्सपैंड कर सकते हैं ।[SEP]
# [CLS] इस फोन में [UNK] एचआरडी स्क्रीन, एलइडी फ्लैश के साथ 10 मेगापिक्सल रियर और 2 मेगापिक्सल फ्रंट कैमरा दिया गया है ।[SEP]
# [CLS] प्रवेश स्तर का ये [UNK] इंच का मॉडल, 1024 [UNK] 600 पिक्सेल आईपीएस डिस्प्ले और अच्छे दृश्य कोणों के साथ उचित कीमत पर उपलब्ध है ।[SEP]
# [CLS] नया नेक्सस [UNK] लेटेस्ट एंड्रायड जेली बीन पर काम करता है ।[SEP]
# [CLS] इसमें प्रोसेसर क्वालकॉम का नया ओक्टा प्रोसेसर स्नैपड्रैगन 61[UNK] दिया गया है जिसमें 64 बिट ऑक्टा कोर प्रोसेसर लगा होता है ।[SEP]
# [CLS] इसके अलावा वाइ - फाइ [UNK] एन [UNK], ब्लूटूथ वी4.0, जीपीएस, ग्लोनैस जैसे कनेक्टिविटी ऑप्शन मौजूद हैं ।[SEP]
# [CLS] ऐसे में इस माडल को खरीदने के साथ ही आपको कम से कम 16 जीबी का एक माइक्रोएसबी कार्ड खरीदना पड़ेगा जिसका मतलब है [UNK]00 से 1000 रुपये का अतिरिक्त खर्च ।[SEP]
# [CLS] माइक्रोमैक्स Microma[UNK] हालांकि कीज keys के प्लेसमेंट के मामले में थोड़ा इनोवेटिव हो सकता था ।[SEP]
# [CLS] पिछले कुछ समय से बाजार में बढ़ती प्रतिद्वंद्विता के चलते 2[UNK]000 रुपये से कम कीमत के लैपटापों की बाजार में भरमार हो गई है ।[SEP]
# [CLS] इस [UNK] का कुल वजन [UNK]3 किलोग्राम है ।[SEP]
# [CLS] हमारे नए [UNK] ब्लूटूथ स्पीकर मोबाइल स्टैंड का भी काम करते हैं ।[SEP]
# [CLS] इसकी 2000m[UNK]h बैटरी एक बार के चार्ज में करीब 12-13 घंटे चली ।[SEP]
# [CLS] इसमें चौड़े एंगल की तस्वीरों के लिए सिंगल मोशन पैनोरमा मोड, स्लो मोशन धीमी गति की वीडियोग्राफी के लिए टाइम लैप्स [UNK] टाइम इंटरवल, अलग - अलग लाइट लेवल के लिए आठ एक्सपोजर लेवल, 30 एफपीएस, [UNK] व्हाइट बैलेंस सेटिंग ऑटो, क्लाउडी, इनकैनडिसेंट, डेलाइट, प्लूरोसेंट, वीजीए और क्यूवीजीए ऑप्शन, वीडियो रिकॉर्डिंग के समय स्नैपशॉट भी मौजूद है ।[SEP]
# [CLS] हुवेई मीडियापैड 10 लिंक की कीमत 24,[UNK] रूपये है, और इस कीमत पर इसे खरीदने की सलाह देना थोड़ा मुश्किल लगता है जबकि इसी कीमत पर बेहतर वैल्यू देने वाला सैमसंग गैलेक्सी नोट [UNK]10 बाज़ार में उपलब्ध है ।[SEP]
# [CLS] [UNK] दम लगा के हईशा [UNK] धीरे - धीरे आपके दिल में उतरती है और सिनेमा हॉल से निकलने के बाद भी आप फिल्म आपके मन में बसी होती है ।[SEP]
# [CLS] विक्रम भट्ट निर्देशित इमरान हाशमी की [UNK] मिस्टर एक्स [UNK] 3डी फिल्म है ।[SEP]
# [CLS] हुवावे मीडिया पैड [UNK] में भी फनबुक पी 600 की तरह [UNK] इंच की स्‍कीन दी गई है ।[SEP]
# [CLS] इसमें 12[UNK]0[UNK]20 पिक्सल्स रेजॉलूशन वाला 4.3 इंच का एचडी आईपीएस डिस्प्ले है ।[SEP]
# [CLS] इसके अलावा, कनेक्टिविटी के लिए यूएसबी 3.0, यूएसबी 2.0 और [UNK]M[UNK] पोर्ट दिए गए हैं ।[SEP]
# [CLS] वे अपनी फिल्में 3डी कैमरे से शूट भी करते हैं, लेकिन इस तकनीकी कुशलता के बावजूद उनकी [UNK] मिस्टर एक्स [UNK] में कथ्य और निर्वाह की कोई नवीनता नहीं दिखती ।[SEP]
# [CLS] रोहतांग में 1[UNK] फीट के करीब बर्फ जमा हो गई थी, जबकि बर्फ से लदे पर्यटन स्थल सोलंग नाला, गुलाबा, राहलाफाल और मढ़ी भी सैलानियों का भरपूर मनोरंजन करने को तैयार हैं ।[SEP]
# [CLS] भारतीय बाजार में इसकी 2[UNK],[UNK]00 रुपये रखी गई है ।[SEP]
# [CLS] फराह खान और शाह रुख खान की पिछली दोनों फिल्में [UNK] मैं हूं ना [UNK] और [UNK] ओम शांति ओम [UNK] से कमजोर फिल्म है [UNK] हैप्पी न्यू ईयर [UNK] ।[SEP]
# [CLS] फेसबुक ने एक नए बटन के तौर पर [UNK] सेंड [UNK] बटन को इस प्रक्रिया में शामिल किया है ।[SEP]
# [CLS] इस फोन में 2[UNK]00 एमएएच की बैटरी लगी है जो काफी लंबे समय तक चलती है ।[SEP]
# [CLS] [UNK].[UNK] इंच की बड़ी स्‍क्रीन के साथ पेश किए गए इनफोकस एम330 में 16 जीबी इंटरनल मैमोरी है ।[SEP]
# [CLS] एमआई 4 आई में डिस्प्ले स्क्रीन [UNK] इंच फुल एचडी है ।[SEP]
# [CLS] आइपी6[UNK] सर्टिफाइड होने के कारण यह धूल और पानी से भी पूरी तरह सुरक्षित है ।[SEP]
# [CLS] लूमिया [UNK]20 [UNK]umia [UNK]20 में डुअल - कोर 1.[UNK] गीगाहर्ट्ज का क्वालकॉम स्नेपड्रैगन एस4 एमएसएम[UNK]60 मोबाइल प्रोसेसर के साथ एड्रीनो 22[UNK] ग्राफिक्स चिप और 1 जीबी की रैम है ।[SEP]
# [CLS] होने की वज़ह से नेक्सस [UNK] का देखने का एंगल बहुत शानदार है ।[SEP]
# [CLS] [UNK].[UNK] इंच की डिस्पले स्क्रीन वाले इस आईपेड में स्लिम एल्युमीनियम बॉडी डिजाइन दिया गया है ।[SEP]
# [CLS] इन स्पीकर का मॉडल [UNK] है, जो स्पीकर के साथ मोबाइल स्टैंड का भी काम करते हैं ।[SEP]
# [CLS] इन स्पीकर की कीमत 3,[UNK] रुपए है ।[SEP]
# [CLS] [UNK] अग्ली [UNK] की कुरूपता समझने के लिए इन गीतों को फिल्म देखने के पहले या बाद में सुन लें तो पूरा नजरिया और संदर्भ मिल जाएगा ।[SEP]
# [CLS] लॉन्च के समय, एयरटेल पॉकेट टीवी सर्विस पर 1[UNK]0 चैनल दे रहा है ।[SEP]
# [CLS] [UNK].[UNK] एमएम पतले इस हैंडसेट का कुल वजन 130 ग्राम है ।[SEP]
# [CLS] इसके साथ ही [UNK] गोल्‍डेन डॉट्स भी हैं, जो चार्जिंग प्‍वॉइंट्स को रिप्रेसेंट करते हैं ।[SEP]
# [CLS] यह कैमरा 6[UNK] डिजीटल जूम को सपोर्ट करता है ।[SEP]
# [CLS] साथ ही, इसे कंट्रोल करने के लिए [UNK] रिमोट भी है ।[SEP]
# [CLS] कंपनी ने इस [UNK]ear [UNK] स्‍मार्टवॉच में यूजर्स के लिये 3जी कनेक्टिविटी की सुविधा दी है ।[SEP]
# [CLS] लेकिन इसमें लगे एएमडी रेडिओन एचडी[UNK]6[UNK]0एम ग्राफ़िक्स चिप का प्रदर्शन लाज़वाब है ।[SEP]
# [CLS] इसके पिछली तरफ 6[UNK]00 m[UNK]h की विशालकाय बैटरी है जिसे पुरे दिन आसानी से इस्तेमाल किया जा सकता है ।[SEP]
# [CLS] निम्न मूल्य वर्ग के टेबलेट्स और स्मार्ट फ़ोन अक्सर सस्ते प्लास्टिक और एक समान डिजाईन में आते हैं, वहीँ डिजिफलीप प्रो [UNK]T[UNK]01 इन दोनों खामियों को दूर करने में कामयाब है |[SEP]
# [CLS] एक और समस्या यह है कि टैबलेट में [UNK] नहीं है जो कि यह जानकर की ए - जीपीएस [UNK] - [UNK] चिप बहुत सस्ती है और इसमें सिम [UNK]M सपोर्ट मौजूद है ।[SEP]
# [CLS] [UNK] एंटर साइन ईजी एप [UNK] के साथ आईफोन [UNK]एस के उपभोक्ताओं की यह परेशानी खत्म हो जाती है ।[SEP]
# [CLS] स्क्रीन पर आप एप्पस एवं [UNK] + [UNK] ऑइकन ऊपर दाहिनी तरफ पाते हैं ।[SEP]
# [CLS] वोस्ट्रो 1[UNK] 3000 लैपटॉप 1366 गुणा [UNK]6[UNK] पिक्सल रेज्योलूशन के साथ 1[UNK].6 इंच एलइडी स्क्रीन के साथ आया है ।[SEP]
# [CLS] गैलेक्सी नोट [UNK]00 के साथ कोई ईयरपीस नहीं दिया गया है, लेकिन कॉल के लिए आप इसके स्पीकर का इस्तेमाल कर सकते हैं, और अगर आप प्राइवेसी चाहते हैं तो इसके साथ दिए गए है डफ़ोन्स का इस्तेमाल कर सकते हैं ।[SEP]
# [CLS] अमेरिकी डॉलर में इसकी कीमत डॉलर 200 यानी करीब 12,6[UNK] रुपए है ।[SEP]
# [CLS] यानी 1[UNK] डिग्री एंगल से भी पिक्चर साफ नजर आएगी ।[SEP]
# [CLS] लॉन्च के समय से ही हरा रंग लूमिया लाइन फोन्स का ट्रेडमार्क रहा है, लूमिया [UNK]30 में भी यह मैट ग्रीन कलर देखा जा सकता है ।[SEP]
# [CLS] शरदिंदु बनर्जी ने 1[UNK]32 में जासूस ब्योमकेश बक्शी के किरदार को गढ़ा था ।[SEP]
# [CLS] इसके डिस्प्ले का रेजोल्यूशन 1366 [UNK] [UNK]6[UNK] पिक्सेल है ।[SEP]
# [CLS] इन सबके अलावा फोन में की इंटरनल मैमोरी [UNK] जीबी है जिसे माइक्रोएसडी कार्ड स्‍लॉट की मदद से 32 जीबी तक एक्‍पेंड कर सकते हैं ।[SEP]
# [CLS] इस डिवाइस में इंटेल का नया कोर M - [UNK]10 प्रोसेसर दिया गया है ।[SEP]
# [CLS] इसके डिस्प्ले में [UNK]20 पी का रेजोलूशन है हालांकि स्क्रीन साइज बढ़ाया गया है फिर भी इसका डिस्प्ले तेज है और जेड1 कॉम्पैक्ट के मुकाबले अधिक ब्राइट है ।[SEP]
# [CLS] [UNK] बेबी [UNK] आतंकवाद पर बनी एक समझदार फिल्म है ।[SEP]
# [CLS] अगर आप 20,000 रूपये तक का टेबलेट खरीदना चाहते हैं, तो आप इसके साथ नेक्सस [UNK], आसुस फोनपैड, जिंक क्वाड [UNK] पर भी विचार कर सकते हैं ।[SEP]
# [CLS] ये दोनों ही फोन 3[UNK] रैम के साथ आते हैं ।[SEP]
# [CLS] वाटर रस्सिटेंस आईपी 6[UNK] 30 मिनट तक एक मीटर गहरे पानी में रखा जा सकता है ।[SEP]
# [CLS] इस डिवाइस का सबसे बड़ा आकर्षण है इसकी कीमत जो कि केवल 11,[UNK]0 रुपये है ।[SEP]
# [CLS] टौरी का ऑटो - फोकस हमारे पसंद आने से थोड़ा धीमा है और सामने [UNK]M[UNK]और रियर कैमरा दोनों कभी कभी फ्लोरोसेंट रोशनी के अंतर्गत संघर्ष करते हैं ।[SEP]
# [CLS] जीबी फ्लैश मैमोरी 32 जीबी एक्‍पेंडेबल मैमोरी एचडीएमआई पोर्ट, ओटीजी केबल फेसबुक, निंबज, नेक्‍टजीटीवी, सावन प्री लोडेड एप्‍लीकेशन कीमत- 4,[UNK] रुपए[SEP]
# [CLS] इसकी स्क्रीन 4.[UNK] इंच की है ।[SEP]
# [CLS] [UNK].6mm पतला ये ईरीडर किंडल सीरीज का सबसे पतला डिवाइस है ।[SEP]
# [CLS] लगभग [UNK]00 वर्ष पुराना मेंहदार का महेंद्रनाथ मंदिर सबसे पुरानी धार्मिक स्थलों में है जो अब लोकप्रिय पर्यटक स्थल है ।[SEP]
# [CLS] [UNK] हैप्पी न्यू इयर [UNK] निश्चित ही आकर्षक, भव्य और रंगीन है ।[SEP]
# [CLS] कैमरे में [UNK] अलग - अलग स्‍पेशल इफेक्‍ट प्रयोग किए जा सकते हैं जैसे नाइट विज़न, सिलहोटे जिन्‍हें यूजर वीडियो और स्‍टिल दोनों तरह से प्रयोग कर सकता है ।[SEP]
# [CLS] नेक्सस 6 गूगल के नये एंड्रायड [UNK] लॉलीपॉप पर चलने वाला पहला स्मार्टफोन है ।[SEP]
# [CLS] सेफ रहने के लिए, टैबलेट ड्ब्ल्यूवीजीए 4[UNK]0[UNK]00 पिक्सल नेटिव रिजॉल्यूशन सपोर्ट करती है ।[SEP]
# [CLS] येरकाड या यरकौद में यूँ तो होटलों की कमी नहीं है पर बीसवें हेयरपिन बेंड के ठीक बाद [UNK]T Nature Trails में अगर ना भी रुकें तो यहाँ एक बार भोजन करना तो बनता है सिर्फ इसलिए नहीं कि यहाँ के व्यंजन लजीज़ हैं बल्कि खासतौर से इसलिए कि यहाँ के [UNK] से आप येरकाड घाटी का अद्भुत नज़ारा देख सकते हैं ।[SEP]
# [CLS] घड़ी को पावर देने के लिए इसपर 410 m[UNK]h की बैट्री दी गई है ।[SEP]
# [CLS] [UNK] जीबी इंटरनल स्टॉरेज है और 32 जीबी तक का माइक्रो - एसडी कार्ड इस्तेमाल किया जा सकता है ।[SEP]
# [CLS] भारी इस्तेमाल के लिए नेक्सस [UNK] बढ़िया है, क्योंकि इस टेबलेट में अच्छा डिस्प्ले, अधिक शक्ति और स्टॉक एंड्रायड इंटरफ़ेस है ।[SEP]
# [CLS] गूगल नेक्सस [UNK] में आपको एंड्रायड का बेहतरीन अनुभव मिलता है ।[SEP]
# [CLS] इस समय 3,[UNK] रु के ख़ास ऑफर पर डिजिफलीप प्रो [UNK]T[UNK]01, प्रदर्शन और विशेषताओं के हिसाब से इस मूल्य वर्ग में पैसा वसूल टेबलेट है |[SEP]
# [CLS] इसमें 2.4गीगाहर्ट्ज़ इंटेल कोर आई[UNK]-3630क्यूएम क्वाडकोर प्रोसेसर है ।[SEP]
# [CLS] इसके अलावा यह 1.2 गीगाहर्त्ज डयूलकोर प्रोसेसर और [UNK]12 जीबी फ्लैश स्टोरेज वेरियंट में भी उतारा गया है ।[SEP]
# [CLS] माइक्रोमैक्स फनबुक में [UNK] इंच का डिसप्ले [UNK]00[UNK]400 पिक्सल रिजॉल्यूशन के साथ है ।[SEP]
# [CLS] माइक्रोमैक्स के इस टेलीविजन का मॉडल [UNK]0[UNK]000[UNK] [UNK] स्पोर्ट्स के नाम से है ।[SEP]
# [CLS] दोनों लैपटॉप एक ही फैमिली के लेकिन अलग वर्ज़न का चिप इस्तेमाल करते हैं, जेड[UNK]0 में जहाँ 1जीबी की चिप है वहीँ डीवी6 में ज्यादा शक्तिशाली 2जीबी का चिप लगा है ।[SEP]
# [CLS] फास्‍ट और स्‍मूद प्रोसेसिंग के लिए लावा ई टैब में 1 गीगाहर्ट सिंगल कोर क्‍वॉलकॉम स्‍नैपड्रैगन प्रोसेसर, एंड्रायड 4.0 आईसीएस ओएस, [UNK]12 एमबी रैम, 4जीबी इंटरनल मैमोरी के अलावा 2 मेगापिक्‍सन रियर और वीडियो कॉलिंग के लिए फ्रंट वीजिए कैमरा इनबिल्‍ड है ।[SEP]
# [CLS] सन् 1[UNK]4 में हुई भोपाल की गैस ट्रैजेडी पर बनी यह फिल्म 20वीं सदी के जानलेवा हादसे की वजहों और प्रभाव को समेट नहीं पाती ।[SEP]
# [CLS] आप चाहे तो इस [UNK]mbilight को अपने हिसाब से कस्टमाइज भी कर सकते है ।[SEP]
# [CLS] इसमें बेहतर प्रोसेसिंग स्पीड के लिए 1.3 गीगाहत्र्ज क्वॉडकोर प्रोसेसर, 2जीबी रैम, [UNK]जीबी इंटरनल मेमोरी दी गई है ।[SEP]
# [CLS] जब हम 3जी 3[UNK] नेटवर्क पर नेट ब्राउज कर रहे थे तब इसकी गरम होने की समस्या सामने आई और यह बार - बार ब्राउजर क्रैश होने के सात ही आधे घंटे में सामने आ गया ।[SEP]
# [CLS] हमने इसकी जाँच आईफोन [UNK]एस के साथ की और पाया कि कैमरा सफेद रंग को नियंत्रित करने और सपूर्ण तस्वीर की गुणवत्ता के मामले में [UNK]एस के बहुत निकट आता है ।[SEP]
# [CLS] लेकिन ध्यान देने की बात ये है, कि बाज़ार में [UNK]20पी डिस्प्ले वाले टेबलेट भी उपलब्ध हैं ।[SEP]
# [CLS] 10[UNK]0 एमएएच रिचार्जेबल लिथियम या 4 एए बैटरी काफी अच्छा फीचर है ।[SEP]
# [CLS] जब इसके स्पेशीफिकेशन पर आते है फनबुक प्रो [UNK]unbook [UNK]ro वास्वत में आंखों को लुभाने वाला है ।[SEP]
# [CLS] कार्बन [UNK]arbonn ने कुछ और एप्स जैसे नेक्सट जीटीवी, इंजेनिक मार्केट एप्स के लिए भी दिये हैं जो विशिष्ट तो नहीं पर उपयोगी जरूर है ।[SEP]
# [CLS] इस टेबलेट में [UNK].[UNK] इंच की एचडी डिस्पले स्क्रीन 204[UNK] [UNK] 1[UNK]36 पिक्सल रेजोल्युशन के साथ दी गई है ।[SEP]
# [CLS] वेद, पुराण, रामायण और महाभारत में इस स्थान को [UNK] प्रयाग [UNK] कहा गया है ।[SEP]
# [CLS] यह टेबलेट विंडोज [UNK].1 ओएस पर काम करता है ।[SEP]
# [CLS] फोन के बैकपैनल पर दी गई [UNK]airline [UNK]rush [UNK]inish भी कंपनी के मुताबिक लग्जरी जैव्लरी में इस्तेमाल होने वाली तकनीक से बनाई गई है ।[SEP]
# [CLS] पावर की po[UNK]er key को इस तरह से रखा गया है, कि आपको इसका पता करने के लिए कुछ समय के लिए थोड़ी कड़ी मेहनत करनी होगी ।[SEP]
# [CLS] भारतीय रेलवे ने रेल राडार [UNK]ail [UNK]adar को लांच किया है, यह ट्रेन ट्रेकिंग सेवा है जो कि गूगल मैप्स [UNK]oogle Maps पर चलती है ।[SEP]
# [CLS] कंपनी ने इसमें 2[UNK]6 जीबी फ्लैश स्टोरेज और इंटेल एचडी ग्राफिक्स दिए हैं ।[SEP]
# [CLS] लेनोवो [UNK]00 उच्च स्तर के प्रदर्शन पर निकलता है जो निर्माता, विंडोज [UNK], द्वारा निर्धारित है ।[SEP]
# [CLS] हालांकि इसमें [UNK] सपोर्ट नहीं है ।[SEP]
# [CLS] दावे के अनुसार यह टैबलेट 3[UNK].[UNK] सेकेंड में बूटअप कर देता है ।[SEP]
# [CLS] माइक्रोमैक्स फनबुक प्रो microma[UNK] [UNK]unbook [UNK]ro माइक्रोमैक्स का नवीनतम टैबलेट है, तथा यह बाजार में 10 इंच वाला सबसे सस्ता टैबलेट है ।[SEP]
# [CLS] जिंक क्वाड [UNK] में सामने की तरफ फ्रंट फेसिंग कैमरा है, और इस पर कोई फिजिकल बटन नहीं है ।[SEP]
# [CLS] इस टैबलेट के साथ उम्दा नियोप्रीन पाउच मिलता है जो बहुत टिकाऊ है, बिना माइक का हैडफोन, स्क्रीन गार्ड, और [UNK] केबल और चार्जर मिलता है ।[SEP]
# [CLS] इसकी स्क्रीन 1[UNK].6 इंच की है ।[SEP]
# [CLS] इसके साथ ही इस वॉच में 320 [UNK] 320 pi[UNK]el का रिजॉल्‍यूशन मिलेगा, वही इसमें 34[UNK]ppi pi[UNK]el की डेन्सिटी भी मिलेगी ।[SEP]
# [CLS] सामान्य इस्तेमाल में इस टेबलेट की बैटरी दो दिन तक चल जाती है, और फिर भी इसमें 2[UNK] प्रतिशत तक बैटरी लाइफ शेष रहती है ।[SEP]
# [CLS] [UNK] अब तक छप्पन 2 [UNK] में सिर्फ नाना ही नहीं बाकी सारे अभिनेता भी नाना जमाने की एक्टिंग कर रहे हैं ।[SEP]
# [CLS] इस स्मार्टफोन में [UNK] जीबी इंटरनल मेमोरी दी गई है, जबकि एक्सटरनल मेमोरी के तौर पर इसमें 32 जीबी तक का माइक्रोएसडी कार्ड लगता है ।[SEP]
# [CLS] इस पार्क को दिसंबर 1[UNK] में वल्र्ड हेरिटेज साइट के रूप में मान्यता मिली ।[SEP]
# [CLS] [UNK]orning [UNK]orilla [UNK]lass 4 की प्रोटेक्शन के साथ, फोन के चारों और दी गई मेटल फ्रेम भी इस बार सैमसंग के फ्लैगशिप फोन को शायद पहली बार [UNK] प्रीमियम [UNK] लुक दे रही है ।[SEP]
# [CLS] ये टीवी 1[UNK] डिग्री व्यूइंग एंगल दिया गया है ।[SEP]
# [CLS] इसके बाद चीन में 4[UNK], स्पेन में 44, फ्रांस में 3[UNK], जर्मनी में 3[UNK], मैक्सिको में 32 और भारत में 32 वल्र्ड हेरिटेज साइट्स हैं ।[SEP]
# [CLS] नीचे की तरफ लगे त्रिकोणीय ढक्कन के अंदर सिम और [UNK] कार्ड का स्थान है जबकि बैटरी टैबलेट के सामान्य नियमानुसार खोली नहीं जा सकती है ।[SEP]
# [CLS] हमें इसमें सिर्फ एक चीज पसंद नहीं आई, वह यह कि इसकी बैटरी सिर्फ 2000m[UNK]h की है ।[SEP]
# [CLS] 36[UNK] मिली एंपियर ऑवर की बैटरी क्षमता, हर्ट रेट मॉनिटर है ।[SEP]
# [CLS] इसमें 1.[UNK] गीगाहर्त्ज ड्यूल - कोर क्वॉलकॉम स्नैपड्रैगन [UNK]4 प्रोसेसर,3[UNK]4 मेगाहर्त्ज वाला एड्रिनो 22[UNK] जीपीयू और 1 जीबी रैम है ।[SEP]
# [CLS] अगर आप 10,000-1[UNK],000 रूपये कीमत के रेंज में टेबलेट खरीदना चाहते हैं तो आप जिंक क्वाड [UNK] पर विचार कर सकते है ।[SEP]
# [CLS] बेंचमार्क टेस्ट में गूगल नेक्सस [UNK] काफी अच्छा परफॉर्म करता है ।[SEP]
# [CLS] 4:3 का अनुपात भी कुछ हद तक माफिक नहीं है बशर्ते आप कोई मूवी देखना चाहते है जिसके लिए 16:[UNK] या 16:10 का अनुपात सही लगता है ।[SEP]
# [CLS] एड्रेनो 30[UNK] जीपीयू बेंचमार्क परिक्षण के तहत कुछ कम क्षमता का साबित हुआ ।[SEP]
# [CLS] इसका स्क्रीन रेजोल्यूशन 1366 [UNK] [UNK]6[UNK] है, जोकि इस कीमत में सामान्यतया होता है ।[SEP]
# [CLS] ये उन लोगों के लिए अच्छा है जिन्हें 4[UNK] की जगह 3[UNK] डाटा पैक डलवाना होता है ।[SEP]
# [CLS] ऑटो - रिक्शा, टैक्सी और बस के जरिए चेन्नई से 4 से [UNK] घंटे में चिदंबरम पहुंचा जा सकता है ।[SEP]
# [CLS] भुवनेश्वर से 211 किमी, बहरामपुर से 16[UNK] किमी और कटक से 1[UNK]2 किमी की दूरी है ।[SEP]
# [CLS] समुद्र तल से लगभग [UNK]602 मीटर 1[UNK],3[UNK]0 फीट की ऊँचाई पर स्थित यह दर्रा विश्व का सबसे ऊँचा दर्रा है ।[SEP]
# [CLS] जियाओमी का यह Mi [UNK]and एक एक्‍टीविटी ट्रैकर की तरह वर्क करता है ।[SEP]
# [CLS] साथ ही, ज़ेडटीइ वी[UNK] की बैट्री काफी प्रभावशाली है, मैंने आसानी से डिवाईस को पूरे दिन इस्तेमाल किया ।[SEP]
# [CLS] हुवेई मीडियापैड 10 लिंक की सलाह देना थोड़ा मुश्किल लगता है, खास कर जबकि इसी कीमत पर बेहतर वैल्यू के साथ सैमसंग गैलेक्सी [UNK]10 बाज़ार में उपलब्ध है ।[SEP]
# [CLS] जबकि पहला रूपांतरण इसे कुछ [UNK] इंच वाले स्मार्टफोन के समान बड़ा बनाता है जबकि दूसरा इसे आपकी हथेली में फिट बैठने लायक बनाता है ।[SEP]
# [CLS] मुझे गलत मत समझे, यह एक बड़ा फोन है, परन्तु यह इतना बड़ा भी नहीं है जितना आप एक [UNK].[UNK] इंच वाले स्मार्टफोन से अपेक्षा करते है ।[SEP]
# [CLS] डब्बावाला - सालों से मुंबई के कार्यालयों में लंचबॉक्स की सेवा देते मशहूर डब्बावाला [UNK] सप्लाई चैन मैनेजमेंट [UNK] का एक बेहतरीन नमूना है ।[SEP]
# [CLS] माइक्रोमैक्स के 42 इंच मॉडल में 3[UNK]40 [UNK] 2160 पिक्सल का रेजोल्यूशन मिलता है ।[SEP]
# [CLS] अपने अन्य समकक्ष प्रतियोगियों की तुलना में नेक्सस [UNK] का स्पेसिफिकेशन काफी बेहतर है ।[SEP]
# [CLS] जिंक क्वाड [UNK] के पीछे के हिस्से में ही बिना फ़्लैश का रियर कैमरा भी है ।[SEP]
# [CLS] बैटरी के परफॉरमेंस टेस्ट में लेनोवो आइडियापैड जेड[UNK]0 सबसे आगे रहता है और इसका क्षमता 1[UNK] मिनट है ।[SEP]
# ...
# [CLS] उसके बाद हर साल 1[UNK] अप्रैल को इंटरनेशनल मोन्यूमेंट्स ऐंड साइट्स डे सेलिब्रेट किया जाता है, जिसे वल्र्ड हेरिटेज डे भी कहा जाता ह[SEP]
# [CLS] इसके अलावा 0.[UNK] cm का स्लिम मेटल बेजल स्क्रीन की साइड बॉडी - be[UNK]el है ।[SEP]
# [CLS] नोकिया आशा [UNK]03 आपकी आशाओ पर पानी फेर सकता है ।[SEP]
# [CLS] Mi [UNK]and का मेजरमेंट 14 [UNK] 36 [UNK] [UNK]mm है जबकि, वेट [UNK] ग्राम है ।[SEP]
# [CLS] 4[UNK] उस डिस्प्ले रेजोल्यूशन को कहा जाता है जिसमें 4000 पिक्सल होते हैं ।[SEP]
# [CLS] डायल पर ओएलईडी [UNK] स्क्रीन के साथ यह साधारण कलाई - घड़ी की तरह ही दिखती है ।[SEP]
# [CLS] यू सीरीज के [UNK]वें जेनरेशन इंटेल कोर प्रोसेसर में दो कोर हैं और इंटेल हाइपर - थ्रेडिंग टेक्नोलॉजी के साथ 4 से ज्यादा थ्रेड्स ।[SEP]
# [CLS] निकोन 1 जे[UNK] कैमरे में अन्य मॉडल्स की तुलना में ज्यादा पावरफुल लैंस दिया गया है ।[SEP]
# [CLS] फिर भी लगता है कि यह समस्या तभी आती है जब आप टैबलेट पर 3जी 3[UNK] नेटवर्क इस्तेमाल कर रहे हों ।[SEP]
# [CLS] दूसरी और ध्यान दें या इसके दूसरे पक्ष क देखें तो यह माइक्रोसॉफ्ट लुमिया 640[UNK] उन लोगों के लिए एक बढ़िया चुनाव है जो साधारण तौर पर स्मार्टफ़ोन के इस्तेमाल करते हैं या जो अपने फ़ोन पर डाक्यूमेंट्स और स्प्रेडशीट आदि पर ज्यादा काम करते हैं ।[SEP]
# [CLS] इसके अलावा [UNK]rbane 3[UNK] में accelerometer, gyroscope, compass, barometer और heart - rate monitor सेंसर भी लगे हुए हैं ।[SEP]
# [CLS] इसका डिस्प्ले [UNK].[UNK] इंच का है और प्लास्टिक बॉडी और ब्रश्ड मेटालिक फिनिश के साथ यह मात्र [UNK].[UNK] मिमी मोटा है ।[SEP]
# [CLS] निकॉन ने पहली बार [UNK]300 नाम से नया डीएसएलआर कैमरा लांच किया है जिसमें जीपीएस और वाईफाई कनेक्‍टीविटी का फीचर दिया गया है यानी आप कैमरे से सीधे अपनी तस्‍वीरें शेयर कर सकते हैं ।[SEP]
# [CLS] बताने की आवश्यकता नहीं है, कि नेक्सस [UNK] का स्टॉक एंड्रायड 4.3 ऑपरेटिंग सिस्टम, दूसरे टेबलेट्स के एंड्रायड 4.2 ओएस से काफी बेहतर है ।[SEP]
# [CLS] बाएं तरफ ही कोएक्सीअल पोर्ट और अतिरिक्त [UNK] पोर्ट दिया गया है साथ ही, यहां हेडफोन और मिनी [UNK] आउट जैक भी मौजूद है ।[SEP]
# [CLS] कंपनी का ये विंडो [UNK] 0.[UNK] टन क्षमता वाला है ।[SEP]
# [CLS] यह भारत का सबसे बड़ा पक्षी अभयारण्य है जो 1[UNK]64 में अभयारण्य और 1[UNK]2 में राष्ट्रीय उद्यान घोषित किया गया था ।[SEP]
# [CLS] लेनोवो सी260-[UNK].[UNK] इंच के डिस्प्ले वाले लेनोवो सी260 लैपटॉप को आल - इन-वन डिवाइस माना गया है क्योंकि यह आपके लिए काम के साथ - साथ मनोरंजन का साधन बनने में भी सक्षम है ।[SEP]
# [CLS] इसमें एएमडी प्रोसेसर है, [UNK]00 जीबी हार्ड डिस्क औ जीबी रैम ।[SEP]
# [CLS] एक्सवर्स्ट प्रोसेसर [UNK]burst processor होने के कारण यह टैबलेट गूगल प्ले [UNK]oogle [UNK]lay के सभी एप्स को सपोर्ट नहीं करता है ।[SEP]
# [CLS] इस स्मार्टफ़ोन में [UNK] मेगापिक्सेल का रियर कैमरा जोकि आपको ऑटो फोकस के साथ एलईडी फ़्लैश के साथ मिल रहा है, इसके साथ ही आपको इस स्मार्टफ़ोन में [UNK] मेगापिक्सेल का फ्रंट फेसिंग कैमरा ब्लिंक प्ले टेक्नोलॉजी के साथ मिल रहा है, यह कैमरा बढ़िया सेल्फी लेने में सक्षम है, साथ ही आप इससे बढ़िया विडियो कॉलिंग का भी लाभ उठा सकते हैं ।[SEP]
# [CLS] विंडोज [UNK].1 ऑपरेटिंग सिस्टम पर काम करने वाला ये टैबलेट 32[UNK] इंटरनल मेमोरी के साथ आता है ।[SEP]
# [CLS] जेनफोन [UNK] एक डुअल सिम डिवाइस है जिसमें 2जी व 3जी दोनों नेटवर्क चलते हैं ।[SEP]
# [CLS] [UNK] मार्गरिटा विद ए स्ट्रॉ [UNK] माता - पिता और बेटी - बेटों के साथ देखी जाने वाली फिल्म है ।[SEP]
# [CLS] सैमसंग गैलेक्सी टैब 2 की मोटाई 10.[UNK] एमएम है, और यह वास्तव में काफी पतला है ।[SEP]
# [CLS] हेडसेट बहुत ही सरल 3.[UNK] mm जैक वाला ओपन ड्राइवर की तरह का ईयरफोन है ।[SEP]
# [CLS] कंपनी का ऐसा दावा है कि [UNK]T[UNK] 6[UNK]bit / s [UNK] हार्ड डिस्क दूसरी ट्रेडिशनल हार्ड डिस्क से छह गुना ज्यादा तेज है ।[SEP]
# [CLS] हालाँकि इसका डिजाईन अगर देखें तो बढ़िया है, इस स्मार्टफ़ोन में आपको कलर फुल पॉलीकार्बोनेट की बैक मिल रही है और इसके साथ ही अगर इसके फ्रंट की बात करेइ[UNK]न तो इसमें प्लास्टिक का फ्रंट है ।[SEP]
# [CLS] इसकी [UNK].[UNK] इंच वाली [UNK]20पी की स्क्रीन आपको भाएगी ।[SEP]
# [CLS] यह वाकई अच्छा है क्योंकि इसमें एंड्रॉयड फोन के साथ आने वाले सामान्य एप्पलीकेशंस की तुलना में [UNK]0 अतिरिक्त एप्प्स हैं ।[SEP]
# [CLS] [UNK] मार्गरिटा विद ए स्ट्रॉ [UNK] सही मायने में रोचक और रोमांचक फिल्म है ।[SEP]
# [CLS] टेलीविजन में ऐप्स इन्सटॉल करने के लिए ऑनबोर्ड [UNK] स्टोरेज है ।[SEP]
# [CLS] ओएलईडी [UNK] स्क्रीन ऐसे भी बेहद छोटा है जबकि इसे यहां नोटिफिकेशन देखने के लिए बनाया गया है जिसमें कॉल रिसीव कराने के अलावा किसी भी नोटिफिकेशन का आअप जवाब नहीं दे सकते ।[SEP]
# [CLS] [UNK] एनएच 10 [UNK] इंडिया और भारत की सच्चाई को कभी आमने - सामने तो कभी समानांतर खड़ी कर देती है ।[SEP]
# [CLS] ये 4[UNK] 3[UNK]40 [UNK] 2160 पिक्सल रेजोल्यूशन डिस्प्ले क्वालिटी को सपोर्ट करता है ।[SEP]
# [CLS] यह टैबलेट एंड्रॉयड 4.0 आईसीएस [UNK]ndroid 4.0 [UNK] पर आधारित है, और इसकी कीमत 12,000 रुपये है ।[SEP]
# [CLS] कीमत 2[UNK] डॉलर ।[SEP]
# [CLS] बाजार में मौजूद अन्य कई ओक्टा - कोर स्मार्टफोनों की तरह यह भी मीडीयाटेक MT6[UNK]2T प्रोसेसर से संचालित है जिसकी क्षमता 1.[UNK] के साथ एआरएम Mali4[UNK]0 M[UNK]4जीपीयू है ।[SEP]
# [CLS] कीमत 3[UNK] डॉलर ।[SEP]
# [CLS] 1.[UNK]6 गीगा हर्ट्ज का इंटेल प्रोसेसर कई बडे टास्क को एक साथ हैंडल कर सकता है ।[SEP]
# [CLS] साथ में [UNK] मेगापिक्‍सल का रियर कैमरा और 0.3 मेगापिक्‍सल का वीजिए फ्रंट फेसिंग कैमरा दिया गया है, इंटरनेट और वॉयस कॉल करने के लिए टैब में सिम स्‍लॉट बना हुआ है ।[SEP]
# [CLS] [UNK]uad [UNK]ore [UNK]rocessor, 1 [UNK] [UNK]M, परफॉरमेंस अच्छी है ।[SEP]
# [CLS] किसी भी व्यक्ति के लिए अपने आपको रंग - बिरंगे जीव जंतुओं और पेड़ पौधे के बीच पाना अद्भूत अनुभव होता है और यद देखना कि स्थानीय जनजाती के लोग अपने विभिन्न रीति रिवाजों और परंपराओं के साथ वहां रह रहे हैं, फूलबानी शहर पूर्वी भारत के मध्य उड़ीसा राज्य में महानदी से लगभग 3[UNK] किमी दक्षिण - पश्चिम में स्थित है ।[SEP]
# [CLS] [UNK] रॉय [UNK] लगातार उलझती और उलझाती जाती है ।[SEP]
# [CLS] हालांकि इसकी कीमत 21[UNK]00 रूपए है ।[SEP]
# [CLS] वहीं तीसरी है 1[UNK] कैरेट गोल्‍ड में उपलब्‍ध [UNK]pple [UNK]atch ।[SEP]
# [CLS] इसकी [UNK]ur[UNK]ed [UNK]dge वाली डिजाइन के अपने अलग फायदे है, जैसे [UNK]ur[UNK]ed [UNK]dges के कारण ये फोन दिखने में [UNK]mm से भी पतला लगता है ।[SEP]
# [CLS] भारतीय बाजार के लिए मोटोरोला का यह [UNK] मोटो एक्स [UNK] उपभोक्ताओं के लिए एक लुभावना मौका है ।[SEP]
# [CLS] खैर हम लोग कबी [UNK]abi और फेनसांग [UNK]hensang तक सड़क के हालात देख मन ही मन राम - राम जपते गए![SEP]
# [CLS] इसके अलावा 1366 गुणा [UNK]6[UNK] पिक्सल के रिजोल्यूशन के साथ हाइ डेफिनेशन एलईडी डिसप्ले बहुत अच्छा है ।[SEP]
# [CLS] डिजाइन के मामले में [UNK]u [UNK]uphoria अच्छा दिखता है ।[SEP]

# %%
for sample in review_datasets["train"]:
    if "HD" in sample["text"]:
        print(sample["text"])
# Out:
# माइक्रोसॉफ्ट सरफेस 3 में 10.8 इंच की क्लियरटाइप फुल HD प्लस डिस्प्ले स्क्रीन है ।
# टैबलेट के दाहिनी उपरी तरफ वाल्यूम रॉकर के बगल में पॉवर ऑन ऑफ बटन है जबकि पोंर्ट्रेट मोड में पकड़ने परा नीचे मिनी HDMI एवं मिनी USB पोर्ट तथा चार्जर की जगह है ।
# इसके अलावा , कनेक्टिविटी के लिए यूएसबी 3.0 , यूएसबी 2.0 और HDMI पोर्ट दिए गए हैं ।
# ये टीवी एंड्रॉइड ऑपरेटिंग सिस्टम पर भी काम करेगी , जिसका मॉडल नंबर MI TV 2 40-Inch Full - HD है ।
# इसी जगह माइक्रोमैक्स के 4K टीवी HD से 8 गुना बेहतर क्वालिटी वाले 42 इंच स्क्रीन वाले टीवी की कीमत 39990 रुपए रखी गई है ।
# माइक्रोमैक्स के इस टेलीविजन का मॉडल 50B5000FHD LED स्पोर्ट्स के नाम से है ।
# टैबलेट के बाई तरफ 3.5 मिमी जैक , एचडीएमआई HDMI , मिनी यूएसवी , माइक्रो एसडी तथा चार्जिंग साकेट के सभी पोर्टस लगे है ।
# माइक्रोमैक्स फनबुक की एक और विशेषता है , इसमें लगा डूअल कोर 400 MHz का ग्राफिक प्रोसेसर जिससे इस डिवाइस पर फुल HD 1080p का वीडियो प्लेबैक की सुविधा भी है , पर एक बार फिर कम डिसप्ले रिजॉल्यूशन हाई डेफिनिशन कॉन्टेंट के मजे को खराब कर देता है जिससे यूजर मिनी HDMI पोर्ट का इस्तेमाल कर इस कॉनटेंट का मजा किसी अन्य बड़े स्कीन पर ले पाता है ।
# स्मार्टफोन्स की आम डाटा केबल में एक साइड USB होता है और दूसरी तरह HDMI है ।
# इसमें काई HDMI केबल नहीं है ।
# एडवांस सॉफ्टवेयर देने के साथ ये टीवी 2HDMI पोर्ट देता है ।
# चूंकि इस पैकेज में कोई HDMI एडॉप्टर शामिल नहीं है , तो यूजर को इसे अलग से ही खरीदना होगा ।
# डिवाइस का सकारात्मक विशेषताओं HDMI के इनपुट , कूलर , काम पर कोई आवाज नहीं , एक सोने मोड ढक्कन बंद करने या सत्ता बटन दबाने में प्रवेश करने की क्षमता शामिल है ।
# यह डोंगल HDMI पोर्ट के साथ आ रहा है , और यह सीधे आपके टीवी और प्रोजेक्टर से जुड़ सकता है ।
# इसी के साथ , स्मार्ट टीवी जो HD क्वालिटी का कंटेंट डिस्प्ले कर सके ।
# HP इलाइटबुक 1020 में 12.5 इंच फुल HD डिस्प्ले है , जो टचस्क्रीन भी है ।
# डिजिफलीप प्रो XT911 FHD रेसोलुशन और एक बड़े 8.9 इंच आईपीएस डिस्प्ले के साथ आता है ।
# इसकी स्क्रीन HD से दोगुना ज्यादा बेहतर क्वालिटी की है ।
# LED के पीछे स्पीकर्स और दूसरा सर्किट दिया है , इनमें ऑडियो पोर्ट , USB पोर्ट , 2 HDMI पोर्ट और VGA पोर्ट शामिल हैं ।
# 4K डिस्प्ले क्वालिटी का मतलब है HD से 8 गुना बेहतर डिस्प्ले क्वालिटी वाला डिवाइस ।
# वो भी फुल HD स्क्रीन 1080 X 1920 Pixels के साथ है ।
# ग्राफिक्स कार्ड स्थापित और समर्पित स्मृति के 2GB के साथ इंटेल HD असतत NVIDIA GeForce जी. टी. 740M है , अच्छा कर रहे हैं ।
# यह इस नोटबुक लेनोवो एक छवि मॉडल के लिए अधिक है कि माना जाता है , हालांकि यह बहुत अच्छा ग्राफिक्स कार्ड के साथ सुसज्जित है , वीडियो प्रोसेसर चौथी पीढ़ी के इंटेल HD , राम के छह गीगाबाइट है ।
# ये HD टीवी 1366 * 768 पिक्सल के रेजोल्यूशन के साथ आता है ।
# इसके पुराने 49 इंच मॉडल में भी ये खासियत थीं जिसमें 4K UHD डिस्प्ले दिया गया था ।
# सिम स्लॉट नीचे की ओर है जबकि बाकी पोर्ट्स जिनमें चार्जिंग स्लॉट , माइक , मिनी यूएसबी , माइक्रो SD स्लॉट , HDMI पोर्ट और 3.5mm जैक टैबलेट के बायें कोने में हैं ।
# अगर इंटेक्स के इस टीवी की तुलना सैमसंग और सोनी ब्राविया मॉडल से की जाए तो 32 इंच की रेंज में HD टीवी के कई मॉडल भारतीय मार्केट में इसी रेंज में मिल जाएंगे ।
# ये अल्ट्रा HD यूजर्स को 8 मिलियन पिक्सल और फुल HD की 2 मिलियन पिक्सल क्वालिटी देती है ।
# ये LED 42 इंच 4K UHD है ।

# %%
def assign_label(example):
    mapping = {"neutral":0, "positive":1, "negative":2}
    example['labels'] = mapping[example['labels']]
    return example

# %%
tokenized_datasets = tokenized_datasets.map(assign_label)
tokenized_datasets.set_format("torch")
tokenized_datasets.column_names
# Out:
# Loading cached processed dataset at C:\Users\arifa\.cache\huggingface\datasets\csv\default-cf2dc84d42ef9241\0.0.0\6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317\cache-5d82cce253ca4f8f.arrow
# Loading cached processed dataset at C:\Users\arifa\.cache\huggingface\datasets\csv\default-800cf891d22db47b\0.0.0\6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317\cache-3e3fe2eb24848d00.arrow
# Loading cached processed dataset at C:\Users\arifa\.cache\huggingface\datasets\csv\default-dc28a06aa2a6c39c\0.0.0\6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317\cache-647c6c8579920861.arrow
# {'train': ['labels', 'input_ids', 'token_type_ids', 'attention_mask'],
#  'validation': ['labels', 'input_ids', 'token_type_ids', 'attention_mask'],
#  'test': ['labels', 'input_ids', 'token_type_ids', 'attention_mask']}

# %%
samples = [tokenized_datasets["train"][i] for i in range(5)]
samples

for chunk in data_collator(samples)["input_ids"]:
    print(f"\n'>>> {tokenizer.decode(chunk)}'")
# Out:
# You're using a PreTrainedTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# '>>> [CLS] एंडराॅयड के मामले में यह थोड़ा पीछे है ।[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]'
#
# '>>> [CLS] यह एस्पेक्ट रेशो का ईश्यू है और हम आशा करते हैं कि यह आने वाले अपडेट में फिक्स कर दिया जाएगा ।[SEP]'
#
# '>>> [CLS] लेकिन इस तरह के एक मॉडल के एक घर कंप्यूटर के लिए एक शानदार विकल्प हो सकता है ।[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]'
#
# '>>> [CLS] गिर वन राष्ट्रीय उद्यान बाघ संरक्षित क्षेत्र है जो एशियाई बब्बर शेर के लिए विश्व प्रसिद्ध है ।[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD][PAD]'
#
# '>>> [CLS] और हां, इस फिल्म में हर किरदार भारद्वाज को भरद्वाज क्यों बुलाता है?[SEP][PAD][PAD][PAD][PAD][PAD][PAD][PAD]'

# %%
review_datasets["train"][:5]
# Out:
# {'labels': ['negative', 'neutral', 'positive', 'positive', 'neutral'],
#  'text': ['एंडराॅयड के मामले में यह थोड़ा पीछे है ।',
#   'यह एस्पेक्ट रेशो का ईश्यू है और हम आशा करते हैं कि यह आने वाले अपडेट में फिक्स कर दिया जाएगा ।',
#   'लेकिन इस तरह के एक मॉडल के एक घर कंप्यूटर के लिए एक शानदार विकल्प हो सकता है ।',
#   'गिर वन राष्ट्रीय उद्यान बाघ संरक्षित क्षेत्र है जो एशियाई बब्बर शेर के लिए विश्व प्रसिद्ध है ।',
#   'और हां , इस फिल्म में हर किरदार भारद्वाज को भरद्वाज क्यों बुलाता है ?']}

# %%
from torch.utils.data import DataLoader
# batch_size = 16
batch_size = 32

train_dataloader = DataLoader(
    tokenized_datasets["train"], shuffle=True, batch_size=batch_size, collate_fn=data_collator
)
eval_dataloader = DataLoader(
    tokenized_datasets["validation"], batch_size=batch_size, collate_fn=data_collator
)

# %%
for batch in train_dataloader:
    break
{k: v.shape for k, v in batch.items()}
# Out:
# {'labels': torch.Size([32]),
#  'input_ids': torch.Size([32, 57]),
#  'token_type_ids': torch.Size([32, 57]),
#  'attention_mask': torch.Size([32, 57])}

# %%
import torch
with torch.no_grad():
    outputs = model(**batch)
    print(outputs.loss, outputs.logits.shape)
# Out:
# tensor(1.0157) torch.Size([32, 3])

# %%
# import numpy as np
# import evaluate

# metric_fun = evaluate.load("accuracy")

# def compute_metrics(eval_preds):
#     logits, labels = eval_preds
#     predictions = np.argmax(logits, axis=-1)

#     metric_result = metric_fun.compute(references=labels, predictions=predictions)
#     return {
#         "accuracy": metric_result["accuracy"],
#     }

# %%
import numpy as np
import evaluate

metric_fun = evaluate.load("f1")

def compute_metrics(eval_preds):
    logits, labels = eval_preds
    predictions = np.argmax(logits, axis=-1)

    metric_result = metric_fun.compute(references=labels, predictions=predictions, average="macro")
    return {
        "f1": metric_result["f1"],
    }

# %%
#  disable weights and biases logging
import os
os.environ["WANDB_DISABLED"] = "true"

# %%
from transformers import TrainingArguments

# batch_size = 16
batch_size = 32
# Show the training loss with every epoch
logging_steps = len(tokenized_datasets["train"]) // batch_size


training_args = TrainingArguments(
    report_to = None,
    output_dir="models/bert-unigram-hindi-classifier",
    overwrite_output_dir=True,
    save_strategy="epoch",
    evaluation_strategy="epoch",
    #learning_rate=2e-5,
    learning_rate=3e-5,
    #weight_decay=0.01,
    weight_decay=0.02,
    #warmup_ratio = 0.1,
    warmup_ratio = 0.05,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    #num_train_epochs=5,
    num_train_epochs=5,
    #push_to_hub=True,
    fp16=True,
    logging_steps=logging_steps,
    #metric_for_best_model = 'accuracy',
    metric_for_best_model = 'f1',
    load_best_model_at_end=True,
)
# Out:
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).

# %%
# from datasets import concatenate_datasets

# entire_train = concatenate_datasets([tokenized_datasets["train"], tokenized_datasets["validation"]])

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    #train_dataset=entire_train,
    eval_dataset=tokenized_datasets["validation"],
    #eval_dataset=tokenized_datasets["test"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

# %%
trainer.train()
# Out:
# C:\Users\arifa\anaconda3\envs\pytorch_env\lib\site-packages\transformers\optimization.py:407: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='545' max='655' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [545/655 01:27 < 00:17, 6.21 it/s, Epoch 4.15/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.743200</td>
#       <td>0.598913</td>
#       <td>0.727696</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.435800</td>
#       <td>0.625464</td>
#       <td>0.735208</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.237600</td>
#       <td>0.668644</td>
#       <td>0.742571</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.112400</td>
#       <td>0.826442</td>
#       <td>0.741990</td>
#     </tr>
#   </tbody>
# </table><p>
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ C:\Users\arifa\AppData\Local\Temp\ipykernel_24688\4032920361.py:1 in <cell line: 1>              │
# │                                                                                                  │
# │ [Errno 2] No such file or directory:                                                             │
# │ 'C:\\Users\\arifa\\AppData\\Local\\Temp\\ipykernel_24688\\4032920361.py'                         │
# │                                                                                                  │
# │ C:\Users\arifa\anaconda3\envs\pytorch_env\lib\site-packages\transformers\trainer.py:1664 in      │
# │ train                                                                                            │
# │                                                                                                  │
# │   1661 │   │   inner_training_loop = find_executable_batch_size(                                 │
# │   1662 │   │   │   self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size  │
# │   1663 │   │   )                                                                                 │
# │ ❱ 1664 │   │   return inner_training_loop(                                                       │
# │   1665 │   │   │   args=args,                                                                    │
# │   1666 │   │   │   resume_from_checkpoint=resume_from_checkpoint,                                │
# │   1667 │   │   │   trial=trial,                                                                  │
# │                                                                                                  │
# │ C:\Users\arifa\anaconda3\envs\pytorch_env\lib\site-packages\transformers\trainer.py:1909 in      │
# │ _inner_training_loop                                                                             │
# │                                                                                                  │
# │   1906 │   │   │   │   rng_to_sync = True                                                        │
# │   1907 │   │   │                                                                                 │
# │   1908 │   │   │   step = -1                                                                     │
# │ ❱ 1909 │   │   │   for step, inputs in enumerate(epoch_iterator):                                │
# │   1910 │   │   │   │   total_batched_samples += 1                                                │
# │   1911 │   │   │   │   if rng_to_sync:                                                           │
# │   1912 │   │   │   │   │   self._load_rng_state(resume_from_checkpoint)                          │
# │                                                                                                  │
# │ C:\Users\arifa\anaconda3\envs\pytorch_env\lib\site-packages\torch\utils\data\dataloader.py:634   │
# │ in __next__                                                                                      │
# │                                                                                                  │
# │    631 │   │   │   if self._sampler_iter is None:                                                │
# │    632 │   │   │   │   # TODO(https://github.com/pytorch/pytorch/issues/76750)                   │
# │    633 │   │   │   │   self._reset()  # type: ignore[call-arg]                                   │
# │ ❱  634 │   │   │   data = self._next_data()                                                      │
# │    635 │   │   │   self._num_yielded += 1                                                        │
# │    636 │   │   │   if self._dataset_kind == _DatasetKind.Iterable and \                          │
# │    637 │   │   │   │   │   self._IterableDataset_len_called is not None and \                    │
# │                                                                                                  │
# │ C:\Users\arifa\anaconda3\envs\pytorch_env\lib\site-packages\torch\utils\data\dataloader.py:678   │
# │ in _next_data                                                                                    │
# │                                                                                                  │
# │    675 │                                                                                         │
# │    676 │   def _next_data(self):                                                                 │
# │    677 │   │   index = self._next_index()  # may raise StopIteration                             │
# │ ❱  678 │   │   data = self._dataset_fetcher.fetch(index)  # may raise StopIteration              │
# │    679 │   │   if self._pin_memory:                                                              │
# │    680 │   │   │   data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)            │
# │    681 │   │   return data                                                                       │
# │                                                                                                  │
# │ C:\Users\arifa\anaconda3\envs\pytorch_env\lib\site-packages\torch\utils\data\_utils\fetch.py:51  │
# │ in fetch                                                                                         │
# │                                                                                                  │
# │   48 │   │   │   if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:         │
# │   49 │   │   │   │   data = self.dataset.__getitems__(possibly_batched_index)                    │
# │   50 │   │   │   else:                                                                           │
# │ ❱ 51 │   │   │   │   data = [self.dataset[idx] for idx in possibly_batched_index]                │
# │   52 │   │   else:                                                                               │
# │   53 │   │   │   data = self.dataset[possibly_batched_index]                                     │
# │   54 │   │   return self.collate_fn(data)                                                        │
# │                                                                                                  │
# │ C:\Users\arifa\anaconda3\envs\pytorch_env\lib\site-packages\torch\utils\data\_utils\fetch.py:51  │
# │ in <listcomp>                                                                                    │
# │                                                                                                  │
# │   48 │   │   │   if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:         │
# │   49 │   │   │   │   data = self.dataset.__getitems__(possibly_batched_index)                    │
# │   50 │   │   │   else:                                                                           │
# │ ❱ 51 │   │   │   │   data = [self.dataset[idx] for idx in possibly_batched_index]                │
# │   52 │   │   else:                                                                               │
# │   53 │   │   │   data = self.dataset[possibly_batched_index]                                     │
# │   54 │   │   return self.collate_fn(data)                                                        │
# │                                                                                                  │
# │ C:\Users\arifa\anaconda3\envs\pytorch_env\lib\site-packages\datasets\arrow_dataset.py:2590 in    │
# │ __getitem__                                                                                      │
# │                                                                                                  │
# │   2587 │                                                                                         │
# │   2588 │   def __getitem__(self, key):  # noqa: F811                                             │
# │   2589 │   │   """Can be used to index columns (by string names) or rows (by integer index or i  │
# │ ❱ 2590 │   │   return self._getitem(                                                             │
# │   2591 │   │   │   key,                                                                          │
# │   2592 │   │   )                                                                                 │
# │   2593                                                                                           │
# │                                                                                                  │
# │ C:\Users\arifa\anaconda3\envs\pytorch_env\lib\site-packages\datasets\arrow_dataset.py:2575 in    │
# │ _getitem                                                                                         │
# │                                                                                                  │
# │   2572 │   │   format_kwargs = format_kwargs if format_kwargs is not None else {}                │
# │   2573 │   │   formatter = get_formatter(format_type, features=self.features, **format_kwargs)   │
# │   2574 │   │   pa_subtable = query_table(self._data, key, indices=self._indices if self._indice  │
# │ ❱ 2575 │   │   formatted_output = format_table(                                                  │
# │   2576 │   │   │   pa_subtable, key, formatter=formatter, format_columns=format_columns, output  │
# │   2577 │   │   )                                                                                 │
# │   2578 │   │   return formatted_output                                                           │
# │                                                                                                  │
# │ C:\Users\arifa\anaconda3\envs\pytorch_env\lib\site-packages\datasets\formatting\formatting.py:63 │
# │ 4 in format_table                                                                                │
# │                                                                                                  │
# │   631 │   query_type = key_to_query_type(key)                                                    │
# │   632 │   python_formatter = PythonFormatter(features=None)                                      │
# │   633 │   if format_columns is None:                                                             │
# │ ❱ 634 │   │   return formatter(pa_table, query_type=query_type)                                  │
# │   635 │   elif query_type == "column":                                                           │
# │   636 │   │   if key in format_columns:                                                          │
# │   637 │   │   │   return formatter(pa_table, query_type)                                         │
# │                                                                                                  │
# │ C:\Users\arifa\anaconda3\envs\pytorch_env\lib\site-packages\datasets\formatting\formatting.py:40 │
# │ 6 in __call__                                                                                    │
# │                                                                                                  │
# │   403 │                                                                                          │
# │   404 │   def __call__(self, pa_table: pa.Table, query_type: str) -> Union[RowFormat, ColumnFo   │
# │   405 │   │   if query_type == "row":                                                            │
# │ ❱ 406 │   │   │   return self.format_row(pa_table)                                               │
# │   407 │   │   elif query_type == "column":                                                       │
# │   408 │   │   │   return self.format_column(pa_table)                                            │
# │   409 │   │   elif query_type == "batch":                                                        │
# │                                                                                                  │
# │ C:\Users\arifa\anaconda3\envs\pytorch_env\lib\site-packages\datasets\formatting\torch_formatter. │
# │ py:83 in format_row                                                                              │
# │                                                                                                  │
# │   80 │   def format_row(self, pa_table: pa.Table) -> Mapping:                                    │
# │   81 │   │   row = self.numpy_arrow_extractor().extract_row(pa_table)                            │
# │   82 │   │   row = self.python_features_decoder.decode_row(row)                                  │
# │ ❱ 83 │   │   return self.recursive_tensorize(row)                                                │
# │   84 │                                                                                           │
# │   85 │   def format_column(self, pa_table: pa.Table) -> "torch.Tensor":                          │
# │   86 │   │   column = self.numpy_arrow_extractor().extract_column(pa_table)                      │
# │                                                                                                  │
# │ C:\Users\arifa\anaconda3\envs\pytorch_env\lib\site-packages\datasets\formatting\torch_formatter. │
# │ py:78 in recursive_tensorize                                                                     │
# │                                                                                                  │
# │   75 │   │   return self._tensorize(data_struct)                                                 │
# │   76 │                                                                                           │
# │   77 │   def recursive_tensorize(self, data_struct: dict):                                       │
# │ ❱ 78 │   │   return map_nested(self._recursive_tensorize, data_struct)                           │
# │   79 │                                                                                           │
# │   80 │   def format_row(self, pa_table: pa.Table) -> Mapping:                                    │
# │   81 │   │   row = self.numpy_arrow_extractor().extract_row(pa_table)                            │
# │                                                                                                  │
# │ C:\Users\arifa\anaconda3\envs\pytorch_env\lib\site-packages\datasets\utils\py_utils.py:444 in    │
# │ map_nested                                                                                       │
# │                                                                                                  │
# │    441 │   if num_proc is None:                                                                  │
# │    442 │   │   num_proc = 1                                                                      │
# │    443 │   if num_proc <= 1 or len(iterable) < parallel_min_length:                              │
# │ ❱  444 │   │   mapped = [                                                                        │
# │    445 │   │   │   _single_map_nested((function, obj, types, None, True, None))                  │
# │    446 │   │   │   for obj in logging.tqdm(iterable, disable=disable_tqdm, desc=desc)            │
# │    447 │   │   ]                                                                                 │
# │                                                                                                  │
# │ C:\Users\arifa\anaconda3\envs\pytorch_env\lib\site-packages\datasets\utils\py_utils.py:445 in    │
# │ <listcomp>                                                                                       │
# │                                                                                                  │
# │    442 │   │   num_proc = 1                                                                      │
# │    443 │   if num_proc <= 1 or len(iterable) < parallel_min_length:                              │
# │    444 │   │   mapped = [                                                                        │
# │ ❱  445 │   │   │   _single_map_nested((function, obj, types, None, True, None))                  │
# │    446 │   │   │   for obj in logging.tqdm(iterable, disable=disable_tqdm, desc=desc)            │
# │    447 │   │   ]                                                                                 │
# │    448 │   else:                                                                                 │
# │                                                                                                  │
# │ C:\Users\arifa\anaconda3\envs\pytorch_env\lib\site-packages\datasets\utils\py_utils.py:346 in    │
# │ _single_map_nested                                                                               │
# │                                                                                                  │
# │    343 │                                                                                         │
# │    344 │   # Singleton first to spare some computation                                           │
# │    345 │   if not isinstance(data_struct, dict) and not isinstance(data_struct, types):          │
# │ ❱  346 │   │   return function(data_struct)                                                      │
# │    347 │                                                                                         │
# │    348 │   # Reduce logging to keep things readable in multiprocessing with tqdm                 │
# │    349 │   if rank is not None and logging.get_verbosity() < logging.WARNING:                    │
# │                                                                                                  │
# │ C:\Users\arifa\anaconda3\envs\pytorch_env\lib\site-packages\datasets\formatting\torch_formatter. │
# │ py:75 in _recursive_tensorize                                                                    │
# │                                                                                                  │
# │   72 │   │   if isinstance(data_struct, np.ndarray):                                             │
# │   73 │   │   │   if data_struct.dtype == object:  # torch tensors cannot be instantied from a    │
# │   74 │   │   │   │   return self._consolidate([self.recursive_tensorize(substruct) for substr    │
# │ ❱ 75 │   │   return self._tensorize(data_struct)                                                 │
# │   76 │                                                                                           │
# │   77 │   def recursive_tensorize(self, data_struct: dict):                                       │
# │   78 │   │   return map_nested(self._recursive_tensorize, data_struct)                           │
# │                                                                                                  │
# │ C:\Users\arifa\anaconda3\envs\pytorch_env\lib\site-packages\datasets\formatting\torch_formatter. │
# │ py:68 in _tensorize                                                                              │
# │                                                                                                  │
# │   65 │   │   │                                                                                   │
# │   66 │   │   │   if isinstance(value, PIL.Image.Image):                                          │
# │   67 │   │   │   │   value = np.asarray(value)                                                   │
# │ ❱ 68 │   │   return torch.tensor(value, **{**default_dtype, **self.torch_tensor_kwargs})         │
# │   69 │                                                                                           │
# │   70 │   def _recursive_tensorize(self, data_struct: dict):                                      │
# │   71 │   │   # support for nested types like struct of list of struct                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt

# %%
trainer.evaluate(tokenized_datasets["test"])
# Out:
# {'eval_loss': 0.2090795636177063,
#  'eval_f1': 0.8600543478260869,
#  'eval_runtime': 0.5485,
#  'eval_samples_per_second': 563.308,
#  'eval_steps_per_second': 18.23,
#  'epoch': 5.0}

# %%
trainer.save_model()

# %%
model = AutoModelForSequenceClassification.from_pretrained("models/bert-unigram-hindi-classifier")
model.to("cuda")
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=1)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=3, bias=True)
# )

# %%
trainer.evaluate(tokenized_datasets["validation"])
# Out:
# {'eval_loss': 0.6686444282531738,
#  'eval_accuracy': 0.7609942638623327,
#  'eval_runtime': 1.0169,
#  'eval_samples_per_second': 514.305,
#  'eval_steps_per_second': 16.717,
#  'epoch': 5.0}
